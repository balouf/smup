# %% [markdown]
# # Using SMUP

# %%
from smup import Smup

# %%
matcher = Smup()
matcher.compute(seed=42)
matcher.display()

# %%
matcher = Smup()
matcher.compute(norm=1, seed=42)
matcher.display()

# %%
matcher = Smup()
matcher.compute(norm="inf", seed=42)
matcher.display()
